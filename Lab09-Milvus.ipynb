# %% [markdown]
# # LAB 9: Full RAG solution with LlamaIndex and Milvus
# In this lab we are going to build a full RAG solution using the LlamaIndex framework that leverages models from the Nvidia NIM API catalog (including LLM and embedding models). For this, you will need an API key from NVIDIA

# %% [markdown]
# <font color="red"><b>IMPORTANT</b></font>: This notebook requires Python 3.11 or older. This can be done by changing the "runtime". Go to "Runtime" > "Change runtime type" and select "2025-07". This will use a kernel with Python 3.11.13

# %%
# !python3 --version
# Out:
# Python 3.11.13

# %% [markdown]
# ## Install dependencies

# %% [markdown]
# The first step is to install the necessary libraries. This installs the core llama-index package which draws a lot of dependencies.

# %%
# !pip install llama-index
# Out:
# Requirement already satisfied: llama-index in /usr/local/lib/python3.11/dist-packages (0.14.14)
# Requirement already satisfied: llama-index-cli<0.6,>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.5.3)
# Requirement already satisfied: llama-index-core<0.15.0,>=0.14.14 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.14.14)
# Requirement already satisfied: llama-index-embeddings-openai<0.6,>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.5.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.9.4)
# Requirement already satisfied: llama-index-llms-openai<0.7,>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.6.18)
# Requirement already satisfied: llama-index-readers-file<0.6,>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.5.6)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.5.1)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/dist-packages (from llama-index) (3.9.1)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (3.11.15)
# Requirement already satisfied: aiosqlite in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (0.22.1)
# Requirement already satisfied: banks<3,>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (2.4.0)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (2025.3.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (0.28.1)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (2.14.2)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (2.0.2)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (11.2.1)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (4.3.8)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (2.11.7)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (2.32.3)
# Requirement already satisfied: setuptools>=80.9.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (82.0.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.14->llama-index) (2.0.41)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (4.14.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15.0,>=0.14.14->llama-index) (1.17.2)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (2.21.0)
# Requirement already satisfied: llama-cloud==0.1.35 in /usr/local/lib/python3.11/dist-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.35)
# Requirement already satisfied: certifi>=2024.7.4 in /usr/local/lib/python3.11/dist-packages (from llama-cloud==0.1.35->llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (2025.7.14)
# Requirement already satisfied: beautifulsoup4<5,>=4.12.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (4.13.4)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (0.7.1)
# Requirement already satisfied: pandas<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.2.2)
# Requirement already satisfied: pypdf<7,>=6.1.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (6.7.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.54)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.14->llama-index) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.14->llama-index) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.14->llama-index) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.14->llama-index) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.14->llama-index) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.14->llama-index) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.14->llama-index) (1.20.1)
# Requirement already satisfied: griffe in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.2.0->llama-index-core<0.15.0,>=0.14.14->llama-index) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.2.0->llama-index-core<0.15.0,>=0.14.14->llama-index) (3.1.6)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5,>=4.12.3->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.7)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.15.0,>=0.14.14->llama-index) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.15.0,>=0.14.14->llama-index) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.15.0,>=0.14.14->llama-index) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.15.0,>=0.14.14->llama-index) (0.16.0)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15.0,>=0.14.14->llama-index) (0.4.2)
# Requirement already satisfied: llama-cloud-services>=0.6.54 in /usr/local/lib/python3.11/dist-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.54)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=2.0.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=2.0.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=2.0.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.14->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.14->llama-index) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.14->llama-index) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.15.0,>=0.14.14->llama-index) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.15.0,>=0.14.14->llama-index) (2.4.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.14->llama-index) (3.2.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.15.0,>=0.14.14->llama-index) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json->llama-index-core<0.15.0,>=0.14.14->llama-index) (3.26.2)
# Requirement already satisfied: python-dotenv<2,>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from llama-cloud-services>=0.6.54->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (1.2.1)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15.0,>=0.14.14->llama-index) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=2.0.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (1.17.0)
# Requirement already satisfied: griffecli==2.0.0 in /usr/local/lib/python3.11/dist-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.15.0,>=0.14.14->llama-index) (2.0.0)
# Requirement already satisfied: griffelib==2.0.0 in /usr/local/lib/python3.11/dist-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.15.0,>=0.14.14->llama-index) (2.0.0)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.11/dist-packages (from griffecli==2.0.0->griffe->banks<3,>=2.2.0->llama-index-core<0.15.0,>=0.14.14->llama-index) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.15.0,>=0.14.14->llama-index) (3.0.2)

# %% [markdown]
# If you look carefully at the previous output you will notice that the only LLM interface that has been installed is OpenAI. We are going to use NVIDIA NIMs including LLMs and Embedding models, so we need to install their corresponding modules.
#
# You can see what LLM modules are available in LlamaIndex in [https://docs.llamaindex.ai/en/stable/module_guides/models/llms/modules/](https://docs.llamaindex.ai/en/stable/module_guides/models/llms/modules/)

# %%
# !pip install llama-index-llms-nvidia llama-index-embeddings-nvidia
# Out:
# Collecting llama-index-llms-nvidia
#   Downloading llama_index_llms_nvidia-0.4.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting llama-index-embeddings-nvidia
#   Downloading llama_index_embeddings_nvidia-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting llama-index-llms-openai-like<0.6,>=0.5.0 (from llama-index-llms-nvidia)
#   Downloading llama_index_llms_openai_like-0.5.3-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: llama-index-core<0.15,>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-embeddings-nvidia) (0.14.14)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (3.11.15)
# Requirement already satisfied: aiosqlite in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (0.22.1)
# Requirement already satisfied: banks<3,>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (2.4.0)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (2025.3.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (0.28.1)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (2.14.2)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (3.5)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (2.0.2)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (11.2.1)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (4.3.8)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (2.11.7)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (2.32.3)
# Requirement already satisfied: setuptools>=80.9.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (82.0.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (2.0.41)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (8.5.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (4.14.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (1.17.2)
# Requirement already satisfied: llama-index-llms-openai<0.7,>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-llms-openai-like<0.6,>=0.5.0->llama-index-llms-nvidia) (0.6.18)
# Requirement already satisfied: transformers<5,>=4.37.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-llms-openai-like<0.6,>=0.5.0->llama-index-llms-nvidia) (4.53.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (1.20.1)
# Requirement already satisfied: griffe in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (3.1.6)
# Requirement already satisfied: openai<3,>=1.108.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-llms-openai<0.7,>=0.6.0->llama-index-llms-openai-like<0.6,>=0.5.0->llama-index-llms-nvidia) (2.21.0)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (0.4.2)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (3.2.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=4.37.0->llama-index-llms-openai-like<0.6,>=0.5.0->llama-index-llms-nvidia) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=4.37.0->llama-index-llms-openai-like<0.6,>=0.5.0->llama-index-llms-nvidia) (0.33.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=4.37.0->llama-index-llms-openai-like<0.6,>=0.5.0->llama-index-llms-nvidia) (24.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=4.37.0->llama-index-llms-openai-like<0.6,>=0.5.0->llama-index-llms-nvidia) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=4.37.0->llama-index-llms-openai-like<0.6,>=0.5.0->llama-index-llms-nvidia) (0.5.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (3.26.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers<5,>=4.37.0->llama-index-llms-openai-like<0.6,>=0.5.0->llama-index-llms-nvidia) (1.1.5)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai<3,>=1.108.1->llama-index-llms-openai<0.7,>=0.6.0->llama-index-llms-openai-like<0.6,>=0.5.0->llama-index-llms-nvidia) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from openai<3,>=1.108.1->llama-index-llms-openai<0.7,>=0.6.0->llama-index-llms-openai-like<0.6,>=0.5.0->llama-index-llms-nvidia) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai<3,>=1.108.1->llama-index-llms-openai<0.7,>=0.6.0->llama-index-llms-openai-like<0.6,>=0.5.0->llama-index-llms-nvidia) (1.3.1)
# Requirement already satisfied: griffecli==2.0.0 in /usr/local/lib/python3.11/dist-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (2.0.0)
# Requirement already satisfied: griffelib==2.0.0 in /usr/local/lib/python3.11/dist-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (2.0.0)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.11/dist-packages (from griffecli==2.0.0->griffe->banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-nvidia) (3.0.2)
# Downloading llama_index_llms_nvidia-0.4.4-py3-none-any.whl (11 kB)
# Downloading llama_index_embeddings_nvidia-0.4.2-py3-none-any.whl (8.1 kB)
# Downloading llama_index_llms_openai_like-0.5.3-py3-none-any.whl (4.7 kB)
# Installing collected packages: llama-index-embeddings-nvidia, llama-index-llms-openai-like, llama-index-llms-nvidia
# Successfully installed llama-index-embeddings-nvidia-0.4.2 llama-index-llms-nvidia-0.4.4 llama-index-llms-openai-like-0.5.3

# %% [markdown]
# Finally, we need to install Milvus itself and the LlamaIndex library to interact with Milvus. For simplicity, in this lab we will use "Milvus Lite". Consider using the standalone or cluster versions for production use cases.

# %%
pip install llama-index-vector-stores-milvus pymilvus[milvus-lite]
# Out:
# Collecting llama-index-vector-stores-milvus
#   Downloading llama_index_vector_stores_milvus-1.0.0-py3-none-any.whl.metadata (385 bytes)
# Collecting pymilvus[milvus-lite]
#   Downloading pymilvus-2.6.9-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: llama-index-core<0.15,>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-vector-stores-milvus) (0.14.14)
# Requirement already satisfied: setuptools>69 in /usr/local/lib/python3.11/dist-packages (from pymilvus[milvus-lite]) (82.0.0)
# Requirement already satisfied: grpcio!=1.68.0,!=1.68.1,!=1.69.0,!=1.70.0,!=1.70.1,!=1.71.0,!=1.72.1,!=1.73.0,>=1.66.2 in /usr/local/lib/python3.11/dist-packages (from pymilvus[milvus-lite]) (1.73.1)
# Requirement already satisfied: orjson>=3.10.15 in /usr/local/lib/python3.11/dist-packages (from pymilvus[milvus-lite]) (3.10.18)
# Requirement already satisfied: protobuf>=5.27.2 in /usr/local/lib/python3.11/dist-packages (from pymilvus[milvus-lite]) (5.29.5)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from pymilvus[milvus-lite]) (1.2.1)
# Requirement already satisfied: pandas>=1.2.4 in /usr/local/lib/python3.11/dist-packages (from pymilvus[milvus-lite]) (2.2.2)
# Requirement already satisfied: cachetools>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from pymilvus[milvus-lite]) (5.5.2)
# Collecting milvus-lite>=2.4.0 (from pymilvus[milvus-lite])
#   Downloading milvus_lite-2.5.1-py3-none-manylinux2014_x86_64.whl.metadata (10.0 kB)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (3.11.15)
# Requirement already satisfied: aiosqlite in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (0.22.1)
# Requirement already satisfied: banks<3,>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (2.4.0)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (2025.3.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (0.28.1)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (2.14.2)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (3.5)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (2.0.2)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (11.2.1)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (4.3.8)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (2.11.7)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (2.32.3)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (2.0.41)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (8.5.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (4.14.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (1.17.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.4->pymilvus[milvus-lite]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.4->pymilvus[milvus-lite]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.4->pymilvus[milvus-lite]) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (1.20.1)
# Requirement already satisfied: griffe in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (0.4.2)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (0.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus[milvus-lite]) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (3.2.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (3.26.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (0.16.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (24.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (1.3.1)
# Requirement already satisfied: griffecli==2.0.0 in /usr/local/lib/python3.11/dist-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (2.0.0)
# Requirement already satisfied: griffelib==2.0.0 in /usr/local/lib/python3.11/dist-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (2.0.0)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.11/dist-packages (from griffecli==2.0.0->griffe->banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-milvus) (3.0.2)
# Downloading llama_index_vector_stores_milvus-1.0.0-py3-none-any.whl (16 kB)
# Downloading milvus_lite-2.5.1-py3-none-manylinux2014_x86_64.whl (55.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 MB 24.7 MB/s eta 0:00:00
# Downloading pymilvus-2.6.9-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.2/301.2 kB 34.8 MB/s eta 0:00:00
# Installing collected packages: milvus-lite, pymilvus, llama-index-vector-stores-milvus
# Successfully installed llama-index-vector-stores-milvus-1.0.0 milvus-lite-2.5.1 pymilvus-2.6.9

# %% [markdown]
# Now we can import the components we need for this lab.

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, StorageContext
from llama_index.core import Settings
from llama_index.llms.nvidia import NVIDIA
from llama_index.embeddings.nvidia import NVIDIAEmbedding
from llama_index.vector_stores.milvus import MilvusVectorStore
import os
import urllib3
urllib3.disable_warnings()

# %% [markdown]
# ## Read environment variables

# %% [markdown]
# A best practice for managing information like the API key is to provide it as an environment variable to the application and get the application to read it from the environment. This is typically done as follows:
# ```
# apikey = os.environ["NVIDIA_API_KEY"]
# ```

# %% [markdown]
# But inside Google Colab we can add them as secrets clicking on the little "key" symbol on the left menu and then read them with "userdata".

# %%
from google.colab import userdata
apikey = userdata.get('apikey')

# %% [markdown]
# ## Instantiate the LLM

# %% [markdown]
# LlamaIndex provides a "Settings" object that stores the most commonly used resources in a LlamaIndex workflow, ex: llm, embed_model. It is a sort of a global storage place for all default settings. If one attribute is not provided anywhere else in the code, the "Settings" object will be queried. As you will see there are several default values that are assumed if not specified. This makes the code look cleaner.
#
# The following line will be sufficient to instantiate an LLM from the Nvidia NIM API if the right defaults apply.

# %%
#Settings.llm = NVIDIA(base_url = llmurl, api_key = apikey)
Settings.llm = NVIDIA(api_key = apikey)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-3178318127.py in <cell line: 0>()
#       1 #Settings.llm = NVIDIA(base_url = llmurl, api_key = apikey) #Use this when using your own local NIM
# ----> 2 Settings.llm = NVIDIA(api_key = apikey)
#
# NameError: name 'NVIDIA' is not defined

# %% [markdown]
# You must define the parameter ```base_url``` when working with NIM's running locally in your environment. If this parameter is not explicitly defined then ```NVIDIA()``` assumes ```base_url = "https://integrate.api.nvidia.com/v1"```
#
# If the parameter ```api_key``` is not omitted then it will try to read the variable ```NVIDIA_API_KEY``` from the environment
#
# Also, like in previous NIM examples, if ```model``` is not present then it will assume ```meta/llama3-8b-instruct```

# %% [markdown]
# So for example, let's say you want to connect to a NIM that is running locally in your datacenter, you want to hard-code the key explicitly in your code and you want to use a Mistral model. Then, the Settings would look like this
# ```
# Settings.llm = NVIDIA(
#     base_url="http://nim-host-address:8000/v1",
#     api_key = "nvapi-123456789abcdefg",
#     model="mistralai/mistral-7b-instruct-v0.2")
# ```

# %% [markdown]
# We can verify what model we are pointing to

# %%
print("... Using: ", Settings.llm.model)
# Out:
# ... Using:  meta/llama3-8b-instruct

# %% [markdown]
# ## Instantiate the embedding model

# %% [markdown]
# We are going to use the "Settings" object again but this time for the embedding model. Instead of requesting a specific embedding model, we leave ```model``` blank and it will select the default one for the Nvidia module, typically 'nv-embedqa-e5-v5'.
#
# Also, similar comments apply here to the need to of defining base_url when using embedding model NIM locally

# %%
#Settings.embed_model = NVIDIAEmbedding(base_url = embedurl, api_key = apikey, truncate="END")
Settings.embed_model = NVIDIAEmbedding(api_key = apikey, truncate="END")
print("... Using: ", Settings.embed_model.model)
# Out:
# ... Using:  nvidia/nv-embedqa-e5-v5

# %% [markdown]
# ## Milvus section

# %% [markdown]
# We are going to instantiate a Milvus vector store. The dimensions need to match the number of dimensions of the embeddings generated by the embedding model we have just chosen above. A quick Google search reveals Nvidia's "nv-embedqa-e5-v5" creates embeddings with 1024 dimensions.
#
# If omitted, the "overwrite" parameter is set to "False". Change it to "True" if you are testing and want to replace the existing collection.
#
# Milvus offers lots of functionality so there many more parameters available. You can check them in the <a href="https://developers.llamaindex.ai/python/framework-api-reference/storage/vector_store/milvus/"  target="_blank">LlamaIndex documentation</a>.

# %%
vector_store = MilvusVectorStore(
    uri="./milvus_demo.db",
    dim=1024,
    collection_name="my_collection",
    overwrite=False
    )

storage_context = StorageContext.from_defaults(vector_store=vector_store)

# %% [markdown]
# ## Load the documents

# %% [markdown]
# Let's use "Simple Directory Reader" to load the documents in the "data" directory. The data directory could also be a mounted directory pointing to PowerScale.
#
# SimpleDirectoryReader will ingest Markdown, PDFs, Word documents, PowerPoint decks, images, audio and video from the specified directory

# %%
# Ensure the "data" directory exist before running the following command
wget 'https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt' -O 'data/paul_graham_essay.txt'
documents = SimpleDirectoryReader("data").load_data()

# %% [markdown]
# ## Create an Index

# %% [markdown]
# Index is a key contruct in the LlamaIndex framework. To build it we need "Documents", an "Embedding model" and a "Storage Context". "Storage Context" could be omited if we want to use the simple in-memory vector store LlamaIndex provides for quick experimentation. But in this case we are going to use Milvus, so we need "storage_context"
#
# Notice also how we are not specifying the ```embed_model``` parameter because it is already defined in the ```Settings``` object

# %%
index = VectorStoreIndex.from_documents(documents, storage_context=storage_context)

# %% [markdown]
# ## Build the query engine

# %% [markdown]
# The final step is to use the "LLM" and the "Index" to build the "Query Engine". Thanks again to the ```Setttings``` object, we don't need to specify ```llm=llm``` or ```embed_model=embed_model```

# %%
query_engine = index.as_query_engine()

# %% [markdown]
# ## Query the RAG solution

# %% [markdown]
# Everything is ready to start querying our RAG solution. We use the ```.query()``` method from the ```query_engine```

# %%
response = query_engine.query("What did the author do growing up?")
print(response)
# Out:
# The author, Paul Graham, grew up in a family that valued education and encouraged his interest in technology and programming.

# %% [markdown]
# ## End of Lab 9
